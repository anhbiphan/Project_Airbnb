# %% [markdown]
# # Cleaning data
# - listing.csv
#     - spliting tables
#     - cleaning the split tables and saving as their own csv file
# <p>
# - creating tables
#     - host.csv
#     - property_features.csv
#     - property_prices.csv
#     - property_reviews.csv
#    </p>

# %%
import pandas as pd

# %%
listings = pd.read_csv('airbnb_dataset/listings.csv')

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0    72635    https://www.airbnb.com/rooms/72635  20151107173015   2015-11-08
# 1  5386323  https://www.airbnb.com/rooms/5386323  20151107173015   2015-11-07
# 2  8826517  https://www.airbnb.com/rooms/8826517  20151107173015   2015-11-07
# 3  8828616  https://www.airbnb.com/rooms/8828616  20151107173015   2015-11-08
# 4  8536913  https://www.airbnb.com/rooms/8536913  20151107173015   2015-11-08
#
#                              name  \
# 0   3 Private Bedrooms, SW Austin
# 1                 Cricket Trailer
# 2  Private room 1 in South Austin
# 3  Private room 2 in South Austin
# 4       Brand-New 3BR Austin Home
#
#                                              summary  \
# 0  Conveniently located 10-15 from downtown in SW...
# 1  Rent this cool concept trailer that has everyt...
# 2  Upstairs, private, 12ft x 13 1/2ft room.  Priv...
# 3  Upstairs, private, 11ft x 13 1/2ft room.  Priv...
# 4  Brand-new 3BR/2BA Austin home with landscaped ...
#
#                                                space  \
# 0  We have three spare bedrooms, each with a quee...
# 1  Rental arrangements for this trailer allows yo...
# 2                                                NaN
# 3                                                NaN
# 4  Feel instantly at home at our brand new 3BR/2B...
#
#                                          description experiences_offered  \
# 0  Conveniently located 10-15 from downtown in SW...                none
# 1  Rent this cool concept trailer that has everyt...                none
# 2  Upstairs, private, 12ft x 13 1/2ft room.  Priv...                none
# 3  Upstairs, private, 11ft x 13 1/2ft room.  Priv...                none
# 4  Brand-new 3BR/2BA Austin home with landscaped ...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Location and convenience are key.  Easy access...  ...                10.0
# 1  We're talking about wherever you'd like in the...  ...                 NaN
# 2                                                NaN  ...                 NaN
# 3                                                NaN  ...                 NaN
# 4  Entertainment and activities are plentiful her...  ...                 NaN
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                f
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy  require_guest_profile_picture  \
# 0            moderate                              f
# 1            moderate                              f
# 2            flexible                              f
# 3            flexible                              f
# 4              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              2
# 3                                f                              2
# 4                                f                              2
#
#   reviews_per_month
# 0              0.02
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 92 columns]

# %%
listings = listings.drop(columns= ['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
       'space', 'description', 'experiences_offered', 'neighborhood_overview',
       'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
       'xl_picture_url', 'host_url','host_about', 'host_thumbnail_url', 'host_picture_url', 'host_listings_count', 'neighbourhood_cleansed',
       'neighbourhood_group_cleansed',  'market',
       'smart_location', 'calendar_updated', 'license', 'jurisdiction_names', 'requires_license'])

# %%
listings.drop([5832], inplace=True)
listings.reset_index(drop=True, inplace=True)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 64 columns):
# id                                  5834 non-null int64
# host_id                             5834 non-null int64
# host_name                           5819 non-null object
# host_since                          5819 non-null object
# host_location                       5809 non-null object
# host_response_time                  4176 non-null object
# host_response_rate                  4176 non-null object
# host_acceptance_rate                3850 non-null object
# host_is_superhost                   5819 non-null object
# host_neighbourhood                  4977 non-null object
# host_total_listings_count           5819 non-null float64
# host_verifications                  5834 non-null object
# host_has_profile_pic                5819 non-null object
# host_identity_verified              5819 non-null object
# street                              5834 non-null object
# neighbourhood                       4800 non-null object
# city                                5834 non-null object
# state                               5834 non-null object
# zipcode                             5809 non-null float64
# country_code                        5834 non-null object
# country                             5834 non-null object
# latitude                            5834 non-null float64
# longitude                           5834 non-null float64
# is_location_exact                   5834 non-null object
# property_type                       5834 non-null object
# room_type                           5834 non-null object
# accommodates                        5834 non-null int64
# bathrooms                           5788 non-null float64
# bedrooms                            5828 non-null float64
# beds                                5811 non-null float64
# bed_type                            5834 non-null object
# amenities                           5834 non-null object
# square_feet                         302 non-null float64
# price                               5834 non-null object
# weekly_price                        2227 non-null object
# monthly_price                       1717 non-null object
# security_deposit                    2770 non-null object
# cleaning_fee                        3586 non-null object
# guests_included                     5834 non-null int64
# extra_people                        5834 non-null object
# minimum_nights                      5834 non-null int64
# maximum_nights                      5834 non-null int64
# has_availability                    5834 non-null object
# availability_30                     5834 non-null int64
# availability_60                     5834 non-null int64
# availability_90                     5834 non-null int64
# availability_365                    5834 non-null int64
# calendar_last_scraped               5834 non-null object
# number_of_reviews                   5834 non-null int64
# first_review                        3826 non-null object
# last_review                         3828 non-null object
# review_scores_rating                3788 non-null float64
# review_scores_accuracy              3775 non-null float64
# review_scores_cleanliness           3777 non-null float64
# review_scores_checkin               3777 non-null float64
# review_scores_communication         3777 non-null float64
# review_scores_location              3778 non-null float64
# review_scores_value                 3777 non-null float64
# instant_bookable                    5834 non-null object
# cancellation_policy                 5834 non-null object
# require_guest_profile_picture       5834 non-null object
# require_guest_phone_verification    5834 non-null object
# calculated_host_listings_count      5834 non-null int64
# reviews_per_month                   3826 non-null float64
# dtypes: float64(16), int64(12), object(36)
# memory usage: 2.8+ MB

# %%
# creating a id column dataframe to concatinate to other tables
id = listings.iloc[:,:1]

# %% [markdown]
# ## Splitting large table into smaller tables

# %% [markdown]
# ### Host table split

# %%
host_cols = listings.columns[:14].tolist()
host = listings.loc[:, (host_cols)]

host.to_csv("host.csv", index=False)

# %%
host.head()
# Out:
#         id   host_id       host_name  host_since  \
# 0    72635    377044  Jason & Marcie  2011-02-04
# 1  5386323  27922117         Michael  2015-02-17
# 2  8826517  46230038             Ric  2015-10-10
# 3  8828616  46230038             Ric  2015-10-10
# 4  8536913  31148752              Bo  2015-04-13
#
#                   host_location  host_response_time host_response_rate  \
# 0  Austin, Texas, United States                 NaN                NaN
# 1  Austin, Texas, United States                 NaN                NaN
# 2  Austin, Texas, United States                 NaN                NaN
# 3  Austin, Texas, United States                 NaN                NaN
# 4                            US  within a few hours                98%
#
#   host_acceptance_rate host_is_superhost host_neighbourhood  \
# 0                  NaN                 f           Circle C
# 1                  NaN                 f           Circle C
# 2                  NaN                 f                NaN
# 3                  NaN                 f                NaN
# 4                  81%                 f              Holly
#
#    host_total_listings_count  \
# 0                        1.0
# 1                        1.0
# 2                        2.0
# 3                        2.0
# 4                      301.0
#
#                                   host_verifications host_has_profile_pic  \
# 0       ['email', 'facebook', 'linkedin', 'reviews']                    t
# 1                ['email', 'phone', 'google', 'kba']                    t
# 2            ['email', 'phone', 'linkedin', 'jumio']                    t
# 3            ['email', 'phone', 'linkedin', 'jumio']                    t
# 4  ['email', 'phone', 'linkedin', 'reviews', 'jum...                    t
#
#   host_identity_verified
# 0                      f
# 1                      t
# 2                      t
# 3                      t
# 4                      t

# %%
host.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 14 columns):
# id                           5834 non-null int64
# host_id                      5834 non-null int64
# host_name                    5819 non-null object
# host_since                   5819 non-null object
# host_location                5809 non-null object
# host_response_time           4176 non-null object
# host_response_rate           4176 non-null object
# host_acceptance_rate         3850 non-null object
# host_is_superhost            5819 non-null object
# host_neighbourhood           4977 non-null object
# host_total_listings_count    5819 non-null float64
# host_verifications           5834 non-null object
# host_has_profile_pic         5819 non-null object
# host_identity_verified       5819 non-null object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 638.2+ KB

# %%
# converting to datetime
host.host_since = pd.to_datetime(host.host_since)

# %%
host.host_response_rate = host.host_response_rate.str.split('%').str[0]

# %%
# converting % into float
host.host_response_rate = host['host_response_rate'].astype(float)

# %%
host.host_response_rate = host.host_response_rate/100

# %% [markdown]
# ---

# %%
# split str to grab numeric value
host.host_acceptance_rate = host.host_acceptance_rate.str.split('%').str[0]

# %%
# converting datatype to float
host.host_acceptance_rate = host.host_acceptance_rate.astype(float)

# %%
# converting to percentage
host.host_acceptance_rate = host.host_acceptance_rate/100

# %% [markdown]
# ---

# %%
# boolean datatype
host.host_is_superhost
# Out:
# 0       f
# 1       f
# 2       f
# 3       f
# 4       f
#        ..
# 5829    f
# 5830    t
# 5831    f
# 5832    f
# 5833    f
# Name: host_is_superhost, Length: 5834, dtype: object

# %%
i = {'t': True, 'f': False}

# %%
# converting datatype to boolean
host.host_is_superhost = host.host_is_superhost.map(i)

host.host_is_superhost = host.host_is_superhost.astype(bool)

# %% [markdown]
# ---

# %%
host.host_has_profile_pic = host.host_has_profile_pic.map(i)
host.host_has_profile_pic = host.host_has_profile_pic.astype(bool)

# %%
host.host_identity_verified = host.host_identity_verified.map(i)
host.host_identity_verified = host.host_identity_verified.astype(bool)

# %%
host.head()
# Out:
#         id   host_id       host_name host_since                 host_location  \
# 0    72635    377044  Jason & Marcie 2011-02-04  Austin, Texas, United States
# 1  5386323  27922117         Michael 2015-02-17  Austin, Texas, United States
# 2  8826517  46230038             Ric 2015-10-10  Austin, Texas, United States
# 3  8828616  46230038             Ric 2015-10-10  Austin, Texas, United States
# 4  8536913  31148752              Bo 2015-04-13                            US
#
#    host_response_time  host_response_rate  host_acceptance_rate  \
# 0                 NaN                 NaN                   NaN
# 1                 NaN                 NaN                   NaN
# 2                 NaN                 NaN                   NaN
# 3                 NaN                 NaN                   NaN
# 4  within a few hours                0.98                  0.81
#
#    host_is_superhost host_neighbourhood  host_total_listings_count  \
# 0              False           Circle C                        1.0
# 1              False           Circle C                        1.0
# 2              False                NaN                        2.0
# 3              False                NaN                        2.0
# 4              False              Holly                      301.0
#
#                                   host_verifications  host_has_profile_pic  \
# 0       ['email', 'facebook', 'linkedin', 'reviews']                  True
# 1                ['email', 'phone', 'google', 'kba']                  True
# 2            ['email', 'phone', 'linkedin', 'jumio']                  True
# 3            ['email', 'phone', 'linkedin', 'jumio']                  True
# 4  ['email', 'phone', 'linkedin', 'reviews', 'jum...                  True
#
#    host_identity_verified
# 0                   False
# 1                    True
# 2                    True
# 3                    True
# 4                    True

# %%
host.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 14 columns):
# id                           5834 non-null int64
# host_id                      5834 non-null int64
# host_name                    5819 non-null object
# host_since                   5819 non-null datetime64[ns]
# host_location                5809 non-null object
# host_response_time           4176 non-null object
# host_response_rate           4176 non-null float64
# host_acceptance_rate         3850 non-null float64
# host_is_superhost            5834 non-null bool
# host_neighbourhood           4977 non-null object
# host_total_listings_count    5819 non-null float64
# host_verifications           5834 non-null object
# host_has_profile_pic         5834 non-null bool
# host_identity_verified       5834 non-null bool
# dtypes: bool(3), datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 518.6+ KB

# %%
host.to_csv("2_host.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# ### Property features table split

# %%
property_features = listings.iloc[:, 14:33]

# %%
property_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 19 columns):
# street               5834 non-null object
# neighbourhood        4800 non-null object
# city                 5834 non-null object
# state                5834 non-null object
# zipcode              5809 non-null float64
# country_code         5834 non-null object
# country              5834 non-null object
# latitude             5834 non-null float64
# longitude            5834 non-null float64
# is_location_exact    5834 non-null object
# property_type        5834 non-null object
# room_type            5834 non-null object
# accommodates         5834 non-null int64
# bathrooms            5788 non-null float64
# bedrooms             5828 non-null float64
# beds                 5811 non-null float64
# bed_type             5834 non-null object
# amenities            5834 non-null object
# square_feet          302 non-null float64
# dtypes: float64(7), int64(1), object(11)
# memory usage: 866.1+ KB

# %%
property_features.head()
# Out:
#                                               street neighbourhood    city  \
# 0  West Slaughter Lane, Austin, TX 78749, United ...      Circle C  Austin
# 1  Seneca Falls Loop, Austin, TX 78739, United St...      Circle C  Austin
# 2       Mordor Cove, Austin, TX 78739, United States           NaN  Austin
# 3       Mordor Cove, Austin, TX 78739, United States           NaN  Austin
# 4   Allamanda Drive, Austin, TX 78739, United States           NaN  Austin
#
#   state  zipcode country_code        country   latitude  longitude  \
# 0    TX  78749.0           US  United States  30.202824 -97.884309
# 1    TX  78739.0           US  United States  30.199414 -97.900684
# 2    TX  78739.0           US  United States  30.168496 -97.864483
# 3    TX  78739.0           US  United States  30.168621 -97.864874
# 4    TX  78739.0           US  United States  30.169426 -97.888319
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 t         House     Private room             6        2.5
# 1                 t     Camper/RV     Private room             2        0.0
# 2                 t         House     Private room             2        1.5
# 3                 t         House     Private room             2        1.5
# 4                 t         House  Entire home/apt             6        2.0
#
#    bedrooms  beds  bed_type  \
# 0       1.0   3.0  Real Bed
# 1       1.0   1.0     Futon
# 2       1.0   1.0  Real Bed
# 3       1.0   1.0  Real Bed
# 4       3.0   3.0  Real Bed
#
#                                            amenities  square_feet
# 0  {"Cable TV",Internet,"Wireless Internet","Air ...       3600.0
# 1  {"Air Conditioning",Heating,"Family/Kid Friend...          NaN
# 2  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN
# 3  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN
# 4  {TV,"Cable TV",Internet,"Wireless Internet","A...          NaN

# %%
property_features.is_location_exact = property_features.is_location_exact.map(i)
property_features.is_location_exact = property_features.is_location_exact.astype(bool)

# %%
property_features = pd.concat([id,property_features], axis=1)

# %%
property_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 20 columns):
# id                   5834 non-null int64
# street               5834 non-null object
# neighbourhood        4800 non-null object
# city                 5834 non-null object
# state                5834 non-null object
# zipcode              5809 non-null float64
# country_code         5834 non-null object
# country              5834 non-null object
# latitude             5834 non-null float64
# longitude            5834 non-null float64
# is_location_exact    5834 non-null bool
# property_type        5834 non-null object
# room_type            5834 non-null object
# accommodates         5834 non-null int64
# bathrooms            5788 non-null float64
# bedrooms             5828 non-null float64
# beds                 5811 non-null float64
# bed_type             5834 non-null object
# amenities            5834 non-null object
# square_feet          302 non-null float64
# dtypes: bool(1), float64(7), int64(2), object(10)
# memory usage: 871.8+ KB

# %%
# property_features.to_csv("2_property_features.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# ### Property Price + Availability table split

# %%
property_price = listings.iloc[:, 33:48]

# %%
property_price = pd.concat([id, property_price], axis=1)

# %%
property_price.head()
# Out:
#         id    price weekly_price monthly_price security_deposit cleaning_fee  \
# 0    72635  $300.00          NaN           NaN              NaN          NaN
# 1  5386323   $99.00      $600.00           NaN        $1,000.00       $75.00
# 2  8826517  $100.00          NaN           NaN              NaN          NaN
# 3  8828616  $100.00          NaN           NaN              NaN          NaN
# 4  8536913  $599.00          NaN           NaN              NaN      $125.00
#
#    guests_included extra_people  minimum_nights  maximum_nights  \
# 0                1        $0.00               2              10
# 1                1        $0.00               3               7
# 2                1        $0.00               1            1125
# 3                1        $0.00               1            1125
# 4                1        $0.00               2            1125
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0                0
# 1                t               29               59               89
# 2                t               30               60               90
# 3                t               30               60               90
# 4                t               27               57               87
#
#    availability_365 calendar_last_scraped
# 0               240            2015-11-07
# 1               364            2015-11-07
# 2               365            2015-11-07
# 3               365            2015-11-07
# 4               358            2015-11-07

# %%
property_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 16 columns):
# id                       5834 non-null int64
# price                    5834 non-null object
# weekly_price             2227 non-null object
# monthly_price            1717 non-null object
# security_deposit         2770 non-null object
# cleaning_fee             3586 non-null object
# guests_included          5834 non-null int64
# extra_people             5834 non-null object
# minimum_nights           5834 non-null int64
# maximum_nights           5834 non-null int64
# has_availability         5834 non-null object
# availability_30          5834 non-null int64
# availability_60          5834 non-null int64
# availability_90          5834 non-null int64
# availability_365         5834 non-null int64
# calendar_last_scraped    5834 non-null object
# dtypes: int64(8), object(8)
# memory usage: 729.4+ KB

# %% [markdown]
# #### Cleaning and organizing datatypes

# %%
# # split the $ symbol
# # replace any commas
# # convert into float
property_price.price = property_price.price.str.split('$').str[1]
property_price.price = property_price.price.replace(',', '', regex=True)
property_price.price = property_price.price.astype(float)

# %%
property_price.weekly_price = property_price.weekly_price.str.split('$').str[1]
property_price.weekly_price = property_price.weekly_price.replace(',', '', regex=True)
property_price.weekly_price = property_price.weekly_price.astype(float)

# %%
property_price.monthly_price = property_price.monthly_price.str.split('$').str[1]
property_price.monthly_price = property_price.monthly_price.replace(',', '', regex=True)
property_price.monthly_price = property_price.monthly_price.astype(float)

# %%
property_price.security_deposit = property_price.security_deposit.str.split('$').str[1]
property_price.security_deposit = property_price.security_deposit.replace(',', '', regex=True)
property_price.security_deposit = property_price.security_deposit.astype(float)

# %%
property_price.cleaning_fee = property_price.cleaning_fee.str.split('$').str[1]
property_price.cleaning_fee = property_price.cleaning_fee.replace(',', '', regex=True)
property_price.cleaning_fee = property_price.cleaning_fee.astype(float)

# %%
property_price.extra_people = property_price.extra_people.str.split('$').str[1]
property_price.extra_people = property_price.extra_people.astype(float)

# %%
# applying boolean datatype
property_price.has_availability = property_price.has_availability.map(i)
property_price.has_availability = property_price.has_availability.astype(bool)

# %%
# converting to datetime
property_price.calendar_last_scraped = pd.to_datetime(property_price.calendar_last_scraped)

# %%
property_price.head(8)
# Out:
#         id  price  weekly_price  monthly_price  security_deposit  \
# 0    72635  300.0           NaN            NaN               NaN
# 1  5386323   99.0         600.0            NaN            1000.0
# 2  8826517  100.0           NaN            NaN               NaN
# 3  8828616  100.0           NaN            NaN               NaN
# 4  8536913  599.0           NaN            NaN               NaN
# 5  8542056  100.0           NaN            NaN               NaN
# 6  6385948   54.0           NaN            NaN               NaN
# 7  8486890   40.0           NaN            NaN               NaN
#
#    cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0           NaN                1           0.0               2
# 1          75.0                1           0.0               3
# 2           NaN                1           0.0               1
# 3           NaN                1           0.0               1
# 4         125.0                1           0.0               2
# 5           NaN                1           0.0               1
# 6          15.0                2          25.0               1
# 7          25.0                2          10.0               1
#
#    maximum_nights  has_availability  availability_30  availability_60  \
# 0              10              True                0                0
# 1               7              True               29               59
# 2            1125              True               30               60
# 3            1125              True               30               60
# 4            1125              True               27               57
# 5            1125              True               30               60
# 6            1125              True                0                0
# 7               7              True               16               16
#
#    availability_90  availability_365 calendar_last_scraped
# 0                0               240            2015-11-07
# 1               89               364            2015-11-07
# 2               90               365            2015-11-07
# 3               90               365            2015-11-07
# 4               87               358            2015-11-07
# 5               90               365            2015-11-07
# 6               26               301            2015-11-07
# 7               37               312            2015-11-07

# %%
property_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 16 columns):
# id                       5834 non-null int64
# price                    5834 non-null float64
# weekly_price             2227 non-null float64
# monthly_price            1717 non-null float64
# security_deposit         2770 non-null float64
# cleaning_fee             3586 non-null float64
# guests_included          5834 non-null int64
# extra_people             5834 non-null float64
# minimum_nights           5834 non-null int64
# maximum_nights           5834 non-null int64
# has_availability         5834 non-null bool
# availability_30          5834 non-null int64
# availability_60          5834 non-null int64
# availability_90          5834 non-null int64
# availability_365         5834 non-null int64
# calendar_last_scraped    5834 non-null datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(6), int64(8)
# memory usage: 689.5 KB

# %%
property_price.to_csv('2_property_price.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# #### Property Review table split

# %%
property_reviews = listings.iloc[:, 48:]

# %%
property_reviews = pd.concat([id, property_reviews], axis=1)

# %%
property_reviews.head()
# Out:
#         id  number_of_reviews first_review last_review  review_scores_rating  \
# 0    72635                  1   2011-03-21  2011-03-21                 100.0
# 1  5386323                  0          NaN         NaN                   NaN
# 2  8826517                  0          NaN         NaN                   NaN
# 3  8828616                  0          NaN         NaN                   NaN
# 4  8536913                  0          NaN         NaN                   NaN
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                     NaN                        NaN                    NaN
# 2                     NaN                        NaN                    NaN
# 3                     NaN                        NaN                    NaN
# 4                     NaN                        NaN                    NaN
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                          NaN                     NaN                  NaN
# 2                          NaN                     NaN                  NaN
# 3                          NaN                     NaN                  NaN
# 4                          NaN                     NaN                  NaN
#
#   instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                f            moderate                             f
# 1                f            moderate                             f
# 2                f            flexible                             f
# 3                f            flexible                             f
# 4                f              strict                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               1
# 1                                f                               1
# 2                                f                               2
# 3                                f                               2
# 4                                f                               2
#
#    reviews_per_month
# 0               0.02
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
property_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 17 columns):
# id                                  5834 non-null int64
# number_of_reviews                   5834 non-null int64
# first_review                        3826 non-null object
# last_review                         3828 non-null object
# review_scores_rating                3788 non-null float64
# review_scores_accuracy              3775 non-null float64
# review_scores_cleanliness           3777 non-null float64
# review_scores_checkin               3777 non-null float64
# review_scores_communication         3777 non-null float64
# review_scores_location              3778 non-null float64
# review_scores_value                 3777 non-null float64
# instant_bookable                    5834 non-null object
# cancellation_policy                 5834 non-null object
# require_guest_profile_picture       5834 non-null object
# require_guest_phone_verification    5834 non-null object
# calculated_host_listings_count      5834 non-null int64
# reviews_per_month                   3826 non-null float64
# dtypes: float64(8), int64(3), object(6)
# memory usage: 775.0+ KB

# %%
property_reviews.first_review = pd.to_datetime(property_reviews.first_review)
property_reviews.last_review = pd.to_datetime(property_reviews.last_review)

# %%
property_reviews.instant_bookable = property_reviews.instant_bookable.map(i)
property_reviews.instant_bookable = property_reviews.instant_bookable.astype(bool)

# %%
property_reviews.require_guest_profile_picture = property_reviews.require_guest_profile_picture.map(i)
property_reviews.require_guest_profile_picture = property_reviews.require_guest_profile_picture.astype(bool)

# %%
property_reviews.require_guest_phone_verification = property_reviews.require_guest_phone_verification.map(i)
property_reviews.require_guest_phone_verification = property_reviews.require_guest_phone_verification.astype(bool)

# %%
property_reviews.head()
# Out:
#         id  number_of_reviews first_review last_review  review_scores_rating  \
# 0    72635                  1   2011-03-21  2011-03-21                 100.0
# 1  5386323                  0          NaT         NaT                   NaN
# 2  8826517                  0          NaT         NaT                   NaN
# 3  8828616                  0          NaT         NaT                   NaN
# 4  8536913                  0          NaT         NaT                   NaN
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                     NaN                        NaN                    NaN
# 2                     NaN                        NaN                    NaN
# 3                     NaN                        NaN                    NaN
# 4                     NaN                        NaN                    NaN
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                          NaN                     NaN                  NaN
# 2                          NaN                     NaN                  NaN
# 3                          NaN                     NaN                  NaN
# 4                          NaN                     NaN                  NaN
#
#    instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0             False            moderate                          False
# 1             False            moderate                          False
# 2             False            flexible                          False
# 3             False            flexible                          False
# 4             False              strict                          False
#
#    require_guest_phone_verification  calculated_host_listings_count  \
# 0                             False                               1
# 1                             False                               1
# 2                             False                               2
# 3                             False                               2
# 4                             False                               2
#
#    reviews_per_month
# 0               0.02
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
property_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5834 entries, 0 to 5833
# Data columns (total 17 columns):
# id                                  5834 non-null int64
# number_of_reviews                   5834 non-null int64
# first_review                        3826 non-null datetime64[ns]
# last_review                         3828 non-null datetime64[ns]
# review_scores_rating                3788 non-null float64
# review_scores_accuracy              3775 non-null float64
# review_scores_cleanliness           3777 non-null float64
# review_scores_checkin               3777 non-null float64
# review_scores_communication         3777 non-null float64
# review_scores_location              3778 non-null float64
# review_scores_value                 3777 non-null float64
# instant_bookable                    5834 non-null bool
# cancellation_policy                 5834 non-null object
# require_guest_profile_picture       5834 non-null bool
# require_guest_phone_verification    5834 non-null bool
# calculated_host_listings_count      5834 non-null int64
# reviews_per_month                   3826 non-null float64
# dtypes: bool(3), datetime64[ns](2), float64(8), int64(3), object(1)
# memory usage: 655.3+ KB

# %%
property_reviews.to_csv('2_property_reviews.csv', index=False)
